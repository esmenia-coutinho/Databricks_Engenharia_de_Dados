# %% [markdown]
# ### Remoção da estrutura DBFS para limpeza de diretórios (Rotina opcional)

# %%
### Rotina de Limpeza de pastas/diretorios

#dbutils.fs.rm("dbfs:/mnt/panex/lhdw/landingzone/processar/", recurse=True)
#dbutils.fs.rm("dbfs:/mnt/panex/lhdw/landingzone/processado/", recurse=True)
#dbutils.fs.rm("dbfs:/mnt/panex/lhdw/bronze", recurse=True)
#dbutils.fs.rm("dbfs:/mnt/panex/lhdw/silver", recurse=True)
#dbutils.fs.rm("dbfs:/mnt/panex/lhdw/gold", recurse=True)
#dbutils.fs.rm("dbfs:/mnt/panex/lhdw/bruto/", recurse=True)
#dbutils.fs.rm("dbfs:/mnt/panex/lhdw/landingzone/", recurse=True)
# Out:
# Out[1]: True

# %% [markdown]
# ### Preparação da estrutura DBFS para atender a arquitetura Medallion

# %%
dbutils.fs.mkdirs("/mnt/panex/lhdw/landingzone/processar/")
dbutils.fs.mkdirs("/mnt/panex/lhdw/landingzone/processado/")
dbutils.fs.mkdirs("/mnt/panex/lhdw/bronze")
dbutils.fs.mkdirs("/mnt/panex/lhdw/silver")
dbutils.fs.mkdirs("/mnt/panex/lhdw/gold")
# Out:
# Out[2]: True

# %% [markdown]
# %md
# ###Conferindo a criação dos diretórios (DBFS)

# %%
display(dbutils.fs.ls("/mnt/panex/lhdw"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/mnt/panex/lhdw/bronze/</td><td>bronze/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/mnt/panex/lhdw/gold/</td><td>gold/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/mnt/panex/lhdw/landingzone/</td><td>landingzone/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/mnt/panex/lhdw/silver/</td><td>silver/</td><td>0</td><td>0</td></tr></tbody></table></div>
